# %% [markdown]
# # crawling data dari twitter

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.6.0.20230303-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 KB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.6.0.20230303

# %%
import pandas as pd
import snscrape.modules.twitter as sracp

# %%
topik = "ganjarpranowo"
tweets = []
limit = 500
for tweet in sracp.TwitterSearchScraper(topik).get_items():
  if limit==0:
    break
  else:
    tweets.append([tweet.user,tweet.content,tweet.place])
    limit-=1
df = pd.DataFrame(tweets, columns=["Akun","Tweet","Lokasi"])
df
# Out:
# <ipython-input-19-0e71c87ec373>:8: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.user,tweet.content,tweet.place])
#                                     Akun  \
# 0          https://twitter.com/trishtayn
# 1          https://twitter.com/trishtayn
# 2           https://twitter.com/DoesDeep
# 3    https://twitter.com/januraendraloka
# 4     https://twitter.com/Ary_Prasetyo85
# ..                                   ...
# 495      https://twitter.com/nonamanisx9
# 496        https://twitter.com/Mi9aWempy
# 497  https://twitter.com/Jarikmerahputih
# 498       https://twitter.com/Georgeni1_
# 499         https://twitter.com/MangPii4
#
#                                                  Tweet Lokasi
# 0    @GanjaranApp @ganjarpranowo Jateng bersyukur n...   None
# 1    @GanjaranApp @ganjarpranowo Pasti seru nih pel...   None
# 2       @ganjarpranowo @jokowi https://t.co/G4OEmfq1E6   None
# 3    @theT4ntryS1 @ganjarpranowo Kepala daerah kan ...   None
# 4    Dari data Dinas Pekerjaan Umum Bina Marga dan ...   None
# ..                                                 ...    ...
# 495  @GanjaranApp @ganjarpranowo Segala bentuk perm...   None
# 496  Simple... \nTapi..,jlebb.. \n\n@ganjarpranowo ...   None
# 497  Duet Ganjar Erick Thohir pasti akan saling mel...   None
# 498  @GanjaranApp @ganjarpranowo @Ganjarmilenial2 P...   None
# 499  @ch_chotimah2 @ganjarpranowo Jalan rusak parah...   None
#
# [500 rows x 3 columns]

# %%
df.to_csv("ganjarpranowo.csv",index=False)

# %% [markdown]
# #crawling dari pta.trunojoyo.ac.id

# %%
_= !pip install bs4

# %%
import requests

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
class ScrapingPtaTrunojoyo:
  def __init__(self, url):
    self.url = url
  
  def page(self):
    res = requests.get(self.url)
    soup = BeautifulSoup(res.content, 'html.parser')
    contents = soup.find('ol', class_='pagination').findChildren(recursive=False)
    return int(contents[-3].text)

  def artikel_page(self, page):
    res = requests.get(f'{self.url}/{page}')
    soup = BeautifulSoup(res.content, 'html.parser')
    contents = soup.find_all('li', attrs={'data-cat':'#luxury'})
    return contents

  def get_berita(self):
    pta_list = []
    page = self.page()
    for pg in range(1, page+1):
      artikels = self.artikel_page(pg)
      for artikel in artikels:
        respone = requests.get(artikel.find('a', class_='gray button')['href'])
        soup_data = BeautifulSoup(respone.content, 'html.parser')
        cont = soup_data.find('div', attrs={'id':'content_journal'})
        # ambil data
        nama = cont.findAll('div')[1].div.span.text.split(' : ')[1]
        judul = str.join("", (cont.find('a', class_='title').string).splitlines()).capitalize()
        abstrak = str.join("", (cont.find('p').string).splitlines()).capitalize()
        pta_list.append({
            'Penulis' : nama,
            'Judul': judul,
            'Abstrak': abstrak
        })
    self.pta = pta_list
  
  def result(self):
    return pd.DataFrame(self.pta)
  
  def save(self, namefile='pta'):
    df = pd.DataFrame(self.pta).to_csv(namefile+'.csv', index=False)

# %%
scPta = ScrapingPtaTrunojoyo('https://pta.trunojoyo.ac.id/c_search/byprod/10/')

# %%
scPta.get_berita()

# %%
scPta.result()
# Out:
#                      Penulis  \
# 0         A.Ubaidillah S.Kom
# 1        M. Basith Ardianto,
# 2      Akhmad Suyandi, S.Kom
# 3            Heri Supriyanto
# 4       Septian Rahman Hakim
# 5        Adi Chandra Laksono
# 6                 NURRACHMAT
# 7      Muhammad Choirur Rozi
# 8            M Khoiril Anwar
# 9             MALIKUL HAMZAH
# 10                    Norman
# 11  Robiatul Adawiyah, S.Kom
# 12       Desy Mariana S. Kom
# 13             Lia Fransiska
# 14            Erwina Safitri
#
#                                                 Judul  \
# 0   Perancangan dan implementasi sistem database t...
# 1   Aplikasi kontrol dan monitoring jaringan kompu...
# 2   Rancang bangun aplikasi proxy server untukenkr...
# 3   Sistem pendukung keputusan optimasi penjadwala...
# 4   Sistem augmented reality animasi benda bergera...
# 5   Gerak pekerja pada game real time strategy men...
# 6   Rancang bangun game perawatan sapi karapan men...
# 7   Ekstraksi fitur berbasis two dimensional linea...
# 8   Implementasi  algoritma prim  dan depth first ...
# 9   Perancangan sistem informasi badan kepegawaian...
# 10  Pemanfaatan togaf adm untuk perancangan sistem...
# 11  Aplikasi metode fuzzy analytic network process...
# 12  Sistem pendukung keputusan rekomendasi menu di...
# 13  Rancang bangun aplikasi pemilihan teknik rekay...
# 14  Deteksi corepoint sidik jari menggunakan metod...
#
#                                               Abstrak
# 0   Sistem  informasi  akademik  (siakad) merupaka...
# 1   Berjalannya koneksi jaringan komputer dengan l...
# 2   Web server adalah sebuah perangkat lunak serve...
# 3   Penjadwalan  kuliah  di  perguruan  tinggi  me...
# 4   Seiring perkembangan teknologi yang ada diduni...
# 5   Gerak pekerja ada pada game yang memiliki genr...
# 6   Perkembangan game yang semakin pesat, memberik...
# 7   Sistem pengenalan wajah adalah suatu sistem un...
# 8   Teknologi mobile game beroperating system open...
# 9   Kantor badan kepegawaian kota bangkalan adalah...
# 10  Penyusunan sistem informasi dinas perindustria...
# 11  Perusahaan pemerintah maupun swasta mempunyai ...
# 12  Pelayanan makanan bagi pasien rawat inap di ru...
# 13  Penyusunan sistem pendukung keputusan pemiliha...
# 14  Sidik jari adalah salah satu karakteristik fis...

# %%
scPta.save()

# %% [markdown]
# #crawling data berita dari cnbc

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv
import pandas as pd
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
def scrape_cnbc(hal):
    global hades
    a = 1
    for page in range(1,hal):
        url_cnbc = f"https://www.cnbcindonesia.com/search?query=kuasa&kanal=&tipe=&date="
        ge = req.get(url_cnbc,hades).text
        sop = bs(ge,'lxml')
        ul = sop.find('ul',class_='list media_rows middle thumb terbaru gtm_indeks_feed')
        li = ul.find_all('li')
        for x in li:
            link_art = x.find('article').find('a')['href']        
            ge_ = req.get(link_art,hades).text
            sop_ = bs(ge_,'lxml')
            art = sop_.find('div',class_='lm_content mt10').find('article')
            headline = art.find('h1').text
            warp = art.find_all('div',class_='detail_text')
            for x in warp:
                x = x.find_all('p')
                y  = [y.text for y in x ]
                content = ''.join(y).replace('\n', '').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
                print(f'done[{a}] > {headline[0:10]}')
                a += 1
                with open('berita.csv','a')as file:
                    wr = csv.writer(file, delimiter=',')
                    wr.writerow([headline,content])

# %%
scrape_cnbc(6)
# Out:
# done[1] > Gegara Raf
# done[2] > Simak! Sed
# done[3] > Tok! Majel
# done[4] > Harta Gono
# done[5] > Marak Peja
# done[6] > Ada PNS Pa
# done[7] > Soal Kasus
# done[8] > Meikarta R
# done[9] > OPM Bikin
# done[10] > Tak Ada Ne
# done[11] > Teror OPM
# done[12] > Tegas! Soa
# done[13] > Gegara Raf
# done[14] > Simak! Sed
# done[15] > Tok! Majel
# done[16] > Harta Gono
# done[17] > Marak Peja
# done[18] > Ada PNS Pa
# done[19] > Soal Kasus
# done[20] > Meikarta R
# done[21] > OPM Bikin
# done[22] > Tak Ada Ne
# done[23] > Teror OPM
# done[24] > Tegas! Soa
# done[25] > Gegara Raf
# done[26] > Simak! Sed
# done[27] > Tok! Majel
# done[28] > Harta Gono
# done[29] > Marak Peja
# done[30] > Ada PNS Pa
# done[31] > Soal Kasus
# done[32] > Meikarta R
# done[33] > OPM Bikin
# done[34] > Tak Ada Ne
# done[35] > Teror OPM
# done[36] > Tegas! Soa
# done[37] > Gegara Raf
# done[38] > Simak! Sed
# done[39] > Tok! Majel
# done[40] > Harta Gono
# done[41] > Marak Peja
# done[42] > Ada PNS Pa
# done[43] > Soal Kasus
# done[44] > Meikarta R
# done[45] > OPM Bikin
# done[46] > Tak Ada Ne
# done[47] > Teror OPM
# done[48] > Tegas! Soa
# done[49] > Gegara Raf
# done[50] > Simak! Sed
# done[51] > Tok! Majel
# done[52] > Harta Gono
# done[53] > Marak Peja
# done[54] > Ada PNS Pa
# done[55] > Soal Kasus
# done[56] > Meikarta R
# done[57] > OPM Bikin
# done[58] > Tak Ada Ne
# done[59] > Teror OPM
# done[60] > Tegas! Soa

# %%
df = pd.read_csv('/content/berita.csv')
df
# Out:
#     Gegara Rafael, Jokowi Minta Kejagung & Polri Bersih-bersih!  \
# 0    Simak! Sederet Dakwaan Bos KSP Sejahtera Iwan ...
# 1    Tok! Majelis Hakim Tolak Permohonan PKPU Terha...
# 2    Harta Gono-Gini Ortu Nagita Berupa Bisnis, Gim...
# 3    Marak Pejabat Pamer Harta, Kemarahan Jokowi Me...
# 4    Ada PNS Pamer Harta, Jokowi Minta Polri & Keja...
# ..                                                 ...
